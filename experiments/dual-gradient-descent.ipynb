# %%
import numpy as np

# %%
class DualGradientDescent:
    def __init__(self, gamma, epsilon, n):
        self.gamma   = gamma
        self.epsilon = epsilon
        self.n       = n
        
        self.lam = np.zeros(n)
        self.mu     = np.zeros(n)
        self.x_sum  = 0
        self.x_0    = np.ones([n, n]) / (n**2)
    
        
        p = np.random.dirichlet(np.ones(n), size=1).ravel()
        q = np.random.dirichlet(np.ones(n), size=1).ravel()
        
    def f(self, x):
        return (self.c * x).sum() + self.gamma * (x * np.log(x / self.x_0)).sum()
    
    def phi(self, lam, mu, n):
        return (lam * self.p).sum() + (mu * self.q).sum() + \
                self.gamma * np.log(1/np.e * (self.x_0 * np.exp(
                    -(self.gamma + self.c + lam.repeat(n).reshape(-1, n) + mu.repeat(n).reshape(-1, n).T) / self.gamma
                )).sum())
        
    def x_hat(self, lam, mu, n):
        x_hat = self.x_0 * np.exp(
            -(self.gamma + self.c + lam.repeat(n).reshape(-1, n) + mu.repeat(n).reshape(-1, n).T) / self.gamma
        )
        return x_hat / x_hat.sum()
    
    def _new_lm(self, p, q):
        x_hat = self.x_hat(self.lam, self.mu, self.n)
        return self.lam - self.gamma * (p - x_hat.sum(1)),\
               self.mu - self.gamma * (q - x_hat.sum(0))
        
    def x_sum_update(self):
        self.x_sum += self.x_hat(self.lam, self.mu, self.n)
        
    def _new_x_wave(self, k):
        return self.x_sum * 1/k
    
    def deviation_p_q(self, x, p, q):
        return np.sqrt(np.sum((x.sum(1) - p)**2) + np.sum((x.sum(0) - q)**2))
    
    def fit(self, c, p, q):
        self.c, self.p, self.q = c, p, q
        
        k = 1
        while True:
            self.lam, self.mu = self._new_lm(self.p, self.q)
            self.x_sum_update()
            self.x_wave = self._new_x_wave(k)
            R = np.sqrt(np.linalg.norm(self.lam) + np.linalg.norm(self.mu))
            epsilon_wave = self.epsilon / R
            
            criteria_a = self.deviation_p_q(self.x_wave, self.p, self.q) < epsilon_wave
            criteria_b = self.f(self.x_wave) + self.phi(self.lam, self.mu, self.n) < self.epsilon
            
            if k % 100 == 0:
                print(f'iteration {k}:   criteria 1 = {round(self.deviation_p_q(self.x_wave, self.p, self.q), 7)}, ' + \
                                     f'criteria 2 = {round(self.f(self.x_wave) + self.phi(self.lam, self.mu, self.n), 7)}')
            
            if criteria_a and criteria_b:
                return self.x_wave, k
            
            k += 1

# %%
def sample_batch(n):
    c = np.random.uniform(0, 10, size=[n, n])
    p = np.random.dirichlet(np.ones(n), size=1).ravel()
    q = np.random.dirichlet(np.ones(n), size=1).ravel()
    return c, p, q

# %%
n = 4
c, p, q = sample_batch(n)
x, k = DualGradientDescent(gamma=0.1, epsilon=1e-2, n=n).fit(c, p, q)
# Out:
# iteration 100:   criteria 1 = 0.2776446, criteria 2 = -0.9580941
# iteration 200:   criteria 1 = 0.1571035, criteria 2 = -0.6667158
# iteration 300:   criteria 1 = 0.1143277, criteria 2 = -0.5631482
# iteration 400:   criteria 1 = 0.093478, criteria 2 = -0.5187149
# iteration 500:   criteria 1 = 0.0813728, criteria 2 = -0.4987456
# iteration 600:   criteria 1 = 0.0735698, criteria 2 = -0.4911919
# iteration 700:   criteria 1 = 0.0681764, criteria 2 = -0.4908029
# iteration 800:   criteria 1 = 0.0642562, criteria 2 = -0.4949251
# iteration 900:   criteria 1 = 0.061296, criteria 2 = -0.5020726
# iteration 1000:   criteria 1 = 0.0589924, criteria 2 = -0.5113475
# iteration 1100:   criteria 1 = 0.0571536, criteria 2 = -0.5221459
# iteration 1200:   criteria 1 = 0.055598, criteria 2 = -0.5331957
# iteration 1300:   criteria 1 = 0.0535068, criteria 2 = -0.5333029
# iteration 1400:   criteria 1 = 0.0503838, criteria 2 = -0.5174254
# iteration 1500:   criteria 1 = 0.0472949, criteria 2 = -0.4993001
# iteration 1600:   criteria 1 = 0.0444614, criteria 2 = -0.4820471
# iteration 1700:   criteria 1 = 0.0418994, criteria 2 = -0.4662382
# iteration 1800:   criteria 1 = 0.0395945, criteria 2 = -0.4519262
# iteration 1900:   criteria 1 = 0.0375203, criteria 2 = -0.438997
# iteration 2000:   criteria 1 = 0.0356485, criteria 2 = -0.4272959
# iteration 2100:   criteria 1 = 0.0339528, criteria 2 = -0.4166714
# iteration 2200:   criteria 1 = 0.0324103, criteria 2 = -0.4069886
# iteration 2300:   criteria 1 = 0.0310015, criteria 2 = -0.3981308
# iteration 2400:   criteria 1 = 0.02971, criteria 2 = -0.3899984
# iteration 2500:   criteria 1 = 0.0285216, criteria 2 = -0.3825066
# iteration 2600:   criteria 1 = 0.0274247, criteria 2 = -0.375583
# iteration 2700:   criteria 1 = 0.026409, criteria 2 = -0.3691655
# iteration 2800:   criteria 1 = 0.0254658, criteria 2 = -0.3632008
# iteration 2900:   criteria 1 = 0.0245877, criteria 2 = -0.3576426
# iteration 3000:   criteria 1 = 0.0237681, criteria 2 = -0.3524507
# iteration 3100:   criteria 1 = 0.0230014, criteria 2 = -0.3475903
# iteration 3200:   criteria 1 = 0.0222826, criteria 2 = -0.3430304
# iteration 3300:   criteria 1 = 0.0216073, criteria 2 = -0.3387442
# iteration 3400:   criteria 1 = 0.0209718, criteria 2 = -0.3347076
# iteration 3500:   criteria 1 = 0.0203726, criteria 2 = -0.3308996
# iteration 3600:   criteria 1 = 0.0198067, criteria 2 = -0.3273011
# iteration 3700:   criteria 1 = 0.0192714, criteria 2 = -0.3238955
# iteration 3800:   criteria 1 = 0.0187643, criteria 2 = -0.3206676
# iteration 3900:   criteria 1 = 0.0182831, criteria 2 = -0.3176038
# iteration 4000:   criteria 1 = 0.0178261, criteria 2 = -0.3146919
# iteration 4100:   criteria 1 = 0.0173913, criteria 2 = -0.311921
# iteration 4200:   criteria 1 = 0.0169772, criteria 2 = -0.3092809
# iteration 4300:   criteria 1 = 0.0165824, criteria 2 = -0.3067628
# iteration 4400:   criteria 1 = 0.0162055, criteria 2 = -0.3043582
# iteration 4500:   criteria 1 = 0.0158454, criteria 2 = -0.3020597
# iteration 4600:   criteria 1 = 0.0155009, criteria 2 = -0.2998604
# iteration 4700:   criteria 1 = 0.0151711, criteria 2 = -0.297754
# iteration 4800:   criteria 1 = 0.014855, criteria 2 = -0.2957348
# iteration 4900:   criteria 1 = 0.0145519, criteria 2 = -0.2937975
# iteration 5000:   criteria 1 = 0.0142608, criteria 2 = -0.2919371
# iteration 5100:   criteria 1 = 0.0139812, criteria 2 = -0.2901492
# iteration 5200:   criteria 1 = 0.0137123, criteria 2 = -0.2884296
# iteration 5300:   criteria 1 = 0.0134536, criteria 2 = -0.2867745
# iteration 5400:   criteria 1 = 0.0132045, criteria 2 = -0.2851802
# iteration 5500:   criteria 1 = 0.0129644, criteria 2 = -0.2836436
# iteration 5600:   criteria 1 = 0.0127329, criteria 2 = -0.2821616
# iteration 5700:   criteria 1 = 0.0125095, criteria 2 = -0.2807312
# iteration 5800:   criteria 1 = 0.0122938, criteria 2 = -0.2793499
# iteration 5900:   criteria 1 = 0.0120855, criteria 2 = -0.2780151
# iteration 6000:   criteria 1 = 0.011884, criteria 2 = -0.2767245
# iteration 6100:   criteria 1 = 0.0116892, criteria 2 = -0.275476
# iteration 6200:   criteria 1 = 0.0115007, criteria 2 = -0.2742675
# iteration 6300:   criteria 1 = 0.0113181, criteria 2 = -0.2730972
# iteration 6400:   criteria 1 = 0.0111413, criteria 2 = -0.2719633
# iteration 6500:   criteria 1 = 0.0109699, criteria 2 = -0.2708641
# iteration 6600:   criteria 1 = 0.0108037, criteria 2 = -0.2697979
# iteration 6700:   criteria 1 = 0.0106424, criteria 2 = -0.2687635
# iteration 6800:   criteria 1 = 0.0104859, criteria 2 = -0.2677593
# iteration 6900:   criteria 1 = 0.0103339, criteria 2 = -0.266784
# iteration 7000:   criteria 1 = 0.0101863, criteria 2 = -0.2658365
# iteration 7100:   criteria 1 = 0.0100428, criteria 2 = -0.2649155
# iteration 7200:   criteria 1 = 0.0099034, criteria 2 = -0.26402
# iteration 7300:   criteria 1 = 0.0097677, criteria 2 = -0.2631489
# iteration 7400:   criteria 1 = 0.0096357, criteria 2 = -0.2623012
# iteration 7500:   criteria 1 = 0.0095072, criteria 2 = -0.261476
# iteration 7600:   criteria 1 = 0.0093821, criteria 2 = -0.2606724
# iteration 7700:   criteria 1 = 0.0092603, criteria 2 = -0.2598896
# iteration 7800:   criteria 1 = 0.0091416, criteria 2 = -0.2591267
# iteration 7900:   criteria 1 = 0.0090258, criteria 2 = -0.2583831
# iteration 8000:   criteria 1 = 0.008913, criteria 2 = -0.257658
# iteration 8100:   criteria 1 = 0.008803, criteria 2 = -0.2569507
# iteration 8200:   criteria 1 = 0.0086956, criteria 2 = -0.2562606
# iteration 8300:   criteria 1 = 0.0085909, criteria 2 = -0.255587
# iteration 8400:   criteria 1 = 0.0084886, criteria 2 = -0.2549294
# iteration 8500:   criteria 1 = 0.0083887, criteria 2 = -0.2542871
# iteration 8600:   criteria 1 = 0.0082912, criteria 2 = -0.2536598
# iteration 8700:   criteria 1 = 0.0081959, criteria 2 = -0.2530468
# iteration 8800:   criteria 1 = 0.0081028, criteria 2 = -0.2524477
# iteration 8900:   criteria 1 = 0.0080117, criteria 2 = -0.2518619
# iteration 9000:   criteria 1 = 0.0079227, criteria 2 = -0.2512892
# iteration 9100:   criteria 1 = 0.0078356, criteria 2 = -0.2507289
# iteration 9200:   criteria 1 = 0.0077505, criteria 2 = -0.2501808
# iteration 9300:   criteria 1 = 0.0076671, criteria 2 = -0.2496445
# iteration 9400:   criteria 1 = 0.0075856, criteria 2 = -0.2491194
# iteration 9500:   criteria 1 = 0.0075057, criteria 2 = -0.2486054
# iteration 9600:   criteria 1 = 0.0074275, criteria 2 = -0.2481021
# iteration 9700:   criteria 1 = 0.0073509, criteria 2 = -0.2476091
# iteration 9800:   criteria 1 = 0.0072759, criteria 2 = -0.2471261
# iteration 9900:   criteria 1 = 0.0072024, criteria 2 = -0.2466528
# iteration 10000:   criteria 1 = 0.0071304, criteria 2 = -0.246189
# iteration 10100:   criteria 1 = 0.0070598, criteria 2 = -0.2457343
# iteration 10200:   criteria 1 = 0.0069906, criteria 2 = -0.2452885
# iteration 10300:   criteria 1 = 0.0069227, criteria 2 = -0.2448513
# iteration 10400:   criteria 1 = 0.0068562, criteria 2 = -0.2444224
# iteration 10500:   criteria 1 = 0.0067909, criteria 2 = -0.2440018
# iteration 10600:   criteria 1 = 0.0067268, criteria 2 = -0.243589
# iteration 10700:   criteria 1 = 0.0066639, criteria 2 = -0.2431839
# iteration 10800:   criteria 1 = 0.0066022, criteria 2 = -0.2427862
# iteration 10900:   criteria 1 = 0.0065417, criteria 2 = -0.2423959
# iteration 11000:   criteria 1 = 0.0064822, criteria 2 = -0.2420126
# iteration 11100:   criteria 1 = 0.0064238, criteria 2 = -0.2416362
# iteration 11200:   criteria 1 = 0.0063664, criteria 2 = -0.2412665
# iteration 11300:   criteria 1 = 0.0063101, criteria 2 = -0.2409033
# iteration 11400:   criteria 1 = 0.0062548, criteria 2 = -0.2405464
# iteration 11500:   criteria 1 = 0.0062004, criteria 2 = -0.2401957
# iteration 11600:   criteria 1 = 0.0061469, criteria 2 = -0.2398511
# iteration 11700:   criteria 1 = 0.0060944, criteria 2 = -0.2395123
# iteration 11800:   criteria 1 = 0.0060427, criteria 2 = -0.2391793
# iteration 11900:   criteria 1 = 0.005992, criteria 2 = -0.2388518
# iteration 12000:   criteria 1 = 0.005942, criteria 2 = -0.2385297
# iteration 12100:   criteria 1 = 0.0058929, criteria 2 = -0.238213
# iteration 12200:   criteria 1 = 0.0058446, criteria 2 = -0.2379014
# iteration 12300:   criteria 1 = 0.0057971, criteria 2 = -0.2375949
# iteration 12400:   criteria 1 = 0.0057503, criteria 2 = -0.2372933
# iteration 12500:   criteria 1 = 0.0057043, criteria 2 = -0.2369965
# iteration 12600:   criteria 1 = 0.0056591, criteria 2 = -0.2367044
# iteration 12700:   criteria 1 = 0.0056145, criteria 2 = -0.2364169
# iteration 12800:   criteria 1 = 0.0055706, criteria 2 = -0.2361339
# iteration 12900:   criteria 1 = 0.0055275, criteria 2 = -0.2358552
# iteration 13000:   criteria 1 = 0.0054849, criteria 2 = -0.2355808
# iteration 13100:   criteria 1 = 0.0054431, criteria 2 = -0.2353106
# iteration 13200:   criteria 1 = 0.0054018, criteria 2 = -0.2350445
# iteration 13300:   criteria 1 = 0.0053612, criteria 2 = -0.2347823
# iteration 13400:   criteria 1 = 0.0053212, criteria 2 = -0.2345241
# iteration 13500:   criteria 1 = 0.0052818, criteria 2 = -0.2342697
# iteration 13600:   criteria 1 = 0.005243, criteria 2 = -0.2340189
# iteration 13700:   criteria 1 = 0.0052047, criteria 2 = -0.2337719
# iteration 13800:   criteria 1 = 0.005167, criteria 2 = -0.2335284
# iteration 13900:   criteria 1 = 0.0051298, criteria 2 = -0.2332884
# iteration 14000:   criteria 1 = 0.0050932, criteria 2 = -0.2330518
# iteration 14100:   criteria 1 = 0.005057, criteria 2 = -0.2328186
# iteration 14200:   criteria 1 = 0.0050214, criteria 2 = -0.2325886
# iteration 14300:   criteria 1 = 0.0049863, criteria 2 = -0.2323618
# iteration 14400:   criteria 1 = 0.0049517, criteria 2 = -0.2321382
# iteration 14500:   criteria 1 = 0.0049175, criteria 2 = -0.2319177
# iteration 14600:   criteria 1 = 0.0048839, criteria 2 = -0.2317001
# iteration 14700:   criteria 1 = 0.0048506, criteria 2 = -0.2314855
# iteration 14800:   criteria 1 = 0.0048179, criteria 2 = -0.2312738
# iteration 14900:   criteria 1 = 0.0047855, criteria 2 = -0.231065
# iteration 15000:   criteria 1 = 0.0047536, criteria 2 = -0.2308589
# iteration 15100:   criteria 1 = 0.0047221, criteria 2 = -0.2306555
# iteration 15200:   criteria 1 = 0.0046911, criteria 2 = -0.2304548
# iteration 15300:   criteria 1 = 0.0046604, criteria 2 = -0.2302567
# iteration 15400:   criteria 1 = 0.0046301, criteria 2 = -0.2300612
# iteration 15500:   criteria 1 = 0.0046003, criteria 2 = -0.2298682
# iteration 15600:   criteria 1 = 0.0045708, criteria 2 = -0.2296776
# iteration 15700:   criteria 1 = 0.0045417, criteria 2 = -0.2294895
# iteration 15800:   criteria 1 = 0.0045129, criteria 2 = -0.2293038
# iteration 15900:   criteria 1 = 0.0044845, criteria 2 = -0.2291204
# iteration 16000:   criteria 1 = 0.0044565, criteria 2 = -0.2289392
# iteration 16100:   criteria 1 = 0.0044288, criteria 2 = -0.2287603
# iteration 16200:   criteria 1 = 0.0044015, criteria 2 = -0.2285836
# iteration 16300:   criteria 1 = 0.0043745, criteria 2 = -0.2284091
# iteration 16400:   criteria 1 = 0.0043478, criteria 2 = -0.2282367
# iteration 16500:   criteria 1 = 0.0043215, criteria 2 = -0.2280664
# iteration 16600:   criteria 1 = 0.0042954, criteria 2 = -0.2278981
# iteration 16700:   criteria 1 = 0.0042697, criteria 2 = -0.2277318
# iteration 16800:   criteria 1 = 0.0042443, criteria 2 = -0.2275675
# iteration 16900:   criteria 1 = 0.0042192, criteria 2 = -0.2274052
# iteration 17000:   criteria 1 = 0.0041944, criteria 2 = -0.2272447
# iteration 17100:   criteria 1 = 0.0041698, criteria 2 = -0.2270861
# iteration 17200:   criteria 1 = 0.0041456, criteria 2 = -0.2269294
# iteration 17300:   criteria 1 = 0.0041216, criteria 2 = -0.2267744
# iteration 17400:   criteria 1 = 0.0040979, criteria 2 = -0.2266213
# iteration 17500:   criteria 1 = 0.0040745, criteria 2 = -0.2264699
# iteration 17600:   criteria 1 = 0.0040514, criteria 2 = -0.2263202
# iteration 17700:   criteria 1 = 0.0040285, criteria 2 = -0.2261721
# iteration 17800:   criteria 1 = 0.0040059, criteria 2 = -0.2260258
# iteration 17900:   criteria 1 = 0.0039835, criteria 2 = -0.225881
# iteration 18000:   criteria 1 = 0.0039613, criteria 2 = -0.2257379
# iteration 18100:   criteria 1 = 0.0039395, criteria 2 = -0.2255964
# iteration 18200:   criteria 1 = 0.0039178, criteria 2 = -0.2254564
# iteration 18300:   criteria 1 = 0.0038964, criteria 2 = -0.2253179
# iteration 18400:   criteria 1 = 0.0038752, criteria 2 = -0.2251809
# iteration 18500:   criteria 1 = 0.0038543, criteria 2 = -0.2250454
# iteration 18600:   criteria 1 = 0.0038336, criteria 2 = -0.2249114
# iteration 18700:   criteria 1 = 0.0038131, criteria 2 = -0.2247788
# iteration 18800:   criteria 1 = 0.0037928, criteria 2 = -0.2246476
# iteration 18900:   criteria 1 = 0.0037727, criteria 2 = -0.2245177
# iteration 19000:   criteria 1 = 0.0037529, criteria 2 = -0.2243893
# iteration 19100:   criteria 1 = 0.0037332, criteria 2 = -0.2242622
# iteration 19200:   criteria 1 = 0.0037138, criteria 2 = -0.2241364
# iteration 19300:   criteria 1 = 0.0036945, criteria 2 = -0.2240119
# iteration 19400:   criteria 1 = 0.0036755, criteria 2 = -0.2238886
# iteration 19500:   criteria 1 = 0.0036566, criteria 2 = -0.2237667
# iteration 19600:   criteria 1 = 0.003638, criteria 2 = -0.223646
# iteration 19700:   criteria 1 = 0.0036195, criteria 2 = -0.2235265
# iteration 19800:   criteria 1 = 0.0036012, criteria 2 = -0.2234082
# iteration 19900:   criteria 1 = 0.0035831, criteria 2 = -0.2232911
# iteration 20000:   criteria 1 = 0.0035652, criteria 2 = -0.2231751
# iteration 20100:   criteria 1 = 0.0035475, criteria 2 = -0.2230603
# iteration 20200:   criteria 1 = 0.0035299, criteria 2 = -0.2229467
# iteration 20300:   criteria 1 = 0.0035125, criteria 2 = -0.2228341
# iteration 20400:   criteria 1 = 0.0034953, criteria 2 = -0.2227227
# iteration 20500:   criteria 1 = 0.0034783, criteria 2 = -0.2226123
# iteration 20600:   criteria 1 = 0.0034614, criteria 2 = -0.2225031
# iteration 20700:   criteria 1 = 0.0034446, criteria 2 = -0.2223948
# iteration 20800:   criteria 1 = 0.0034281, criteria 2 = -0.2222876
# iteration 20900:   criteria 1 = 0.0034117, criteria 2 = -0.2221814
# iteration 21000:   criteria 1 = 0.0033954, criteria 2 = -0.2220763
# iteration 21100:   criteria 1 = 0.0033793, criteria 2 = -0.2219721
# iteration 21200:   criteria 1 = 0.0033634, criteria 2 = -0.2218689
# iteration 21300:   criteria 1 = 0.0033476, criteria 2 = -0.2217667
# iteration 21400:   criteria 1 = 0.003332, criteria 2 = -0.2216654
# iteration 21500:   criteria 1 = 0.0033165, criteria 2 = -0.2215651
# iteration 21600:   criteria 1 = 0.0033011, criteria 2 = -0.2214657
# iteration 21700:   criteria 1 = 0.0032859, criteria 2 = -0.2213672
# iteration 21800:   criteria 1 = 0.0032708, criteria 2 = -0.2212696
# iteration 21900:   criteria 1 = 0.0032559, criteria 2 = -0.2211729
# iteration 22000:   criteria 1 = 0.0032411, criteria 2 = -0.2210771
# iteration 22100:   criteria 1 = 0.0032264, criteria 2 = -0.2209821
# iteration 22200:   criteria 1 = 0.0032119, criteria 2 = -0.220888
# iteration 22300:   criteria 1 = 0.0031975, criteria 2 = -0.2207947
# iteration 22400:   criteria 1 = 0.0031832, criteria 2 = -0.2207023
# iteration 22500:   criteria 1 = 0.0031691, criteria 2 = -0.2206107
# iteration 22600:   criteria 1 = 0.0031551, criteria 2 = -0.2205199
# iteration 22700:   criteria 1 = 0.0031412, criteria 2 = -0.2204299
# iteration 22800:   criteria 1 = 0.0031274, criteria 2 = -0.2203406

# %%
x, k
# Out:
# (array([[  1.58094222e-06,   5.16658885e-33,   4.56296538e-02,
#            6.03921059e-04],
#         [  6.24949303e-26,   3.77502695e-03,   4.87886504e-02,
#            3.13048681e-01],
#         [  9.39614887e-03,   3.20481079e-01,   7.97871231e-05,
#            2.17367717e-02],
#         [  1.92459938e-14,   2.36442617e-01,   1.60819380e-05,
#            5.07543573e-31]]), 22800)
